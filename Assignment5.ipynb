# %% [markdown]
# <a href="https://colab.research.google.com/github/GuptaShivam007/Assignments/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Q1

# %%
dataset=pd.read_csv('company_sales_data.csv')
y=dataset.iloc[:,-1]
x=dataset.iloc[:,0]

# %%
sns.lineplot(x=x,y=y)
plt.show()

# %%
y1=dataset.iloc[:,1]
y2=dataset.iloc[:,2]
y3=dataset.iloc[:,3]
y4=dataset.iloc[:,4]
y5=dataset.iloc[:,5]
y6=dataset.iloc[:,6]
y7=dataset.iloc[:,7]
y8=dataset.iloc[:,8]

# %%
sns.lineplot(x=x,y=y1)
sns.lineplot(x=x,y=y2)
sns.lineplot(x=x,y=y3)
sns.lineplot(x=x,y=y4)
sns.lineplot(x=x,y=y5)
sns.lineplot(x=x,y=y6)
plt.ylabel('Products')
plt.xlabel('Months')
plt.show()

# %%
sns.barplot(x=x,y=y1)
sns.barplot(x=x,y=y2)
sns.barplot(x=x,y=y3)
sns.barplot(x=x,y=y4)
sns.barplot(x=x,y=y5)
sns.barplot(x=x,y=y6)
sns.barplot(x=x,y=y7)
sns.barplot(x=x,y=y8)
plt.ylabel('Products')
plt.xlabel('Months')
plt.show()

# %% [markdown]
# Q2

# %%
fig = px.scatter(x=x, y=y1)

# Customize layout (optional)
fig.update_layout(title='Sales Data', xaxis_title='Month', yaxis_title='Facecream')
# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Q3

# %%
fig=px.bar(x=x,y=y1)
fig=px.bar(x=x,y=y2)
fig=px.bar(x=x,y=y3)
fig=px.bar(x=x,y=y4)
fig=px.bar(x=x,y=y5)
fig=px.bar(x=x,y=y6)
fig.update_layout(title="Sales Data",xaxis_title="Months",yaxis_title="Products")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Q4

# %%
fig=px.histogram(x=x,y=y1,)
fig=px.histogram(x=x,y=y2)
fig=px.histogram(x=x,y=y3)
fig=px.histogram(x=x,y=y4)
fig=px.histogram(x=x,y=y5)
fig=px.histogram(x=x,y=y6)
fig.update_layout(title="Sales Data",xaxis_title="Months",yaxis_title="Products")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# True
